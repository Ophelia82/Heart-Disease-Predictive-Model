# %%
import pandas as pd
import numpy as np

# %%
#reading in the prepared training data.  currently, data is not scaled.
df = pd.read_excel('data/clean2.xlsx')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 0   63    1   1       145   233    1        60      0    0
# 1   67    1   4       160   286    0        64      1    2
# 2   67    1   4       120   229    0        78      1    1
# 3   37    1   3       130   250    0        84      0    0
# 4   41    0   2       130   204    0        71      0    0

# %%
df.loc[df['num'] == 2, 'num'] = 1

# %%
df.loc[df['num'] == 3, 'num'] = 2

# %%
df.loc[df['num'] == 4, 'num'] = 2

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 0     63    1   1       145   233    1        60      0    0
# 1     67    1   4       160   286    0        64      1    1
# 2     67    1   4       120   229    0        78      1    1
# 3     37    1   3       130   250    0        84      0    0
# 4     41    0   2       130   204    0        71      0    0
# 5     56    1   2       120   236    0        73      0    0
# 6     62    0   4       140   268    0        83      0    2
# 7     57    0   4       120   354    0        84      1    0
# 8     63    1   4       130   254    0        75      0    1
# 9     53    1   4       140   203    1        86      1    1
# 10    57    1   4       140   192    0        86      0    0
# 11    56    0   2       140   294    0        85      0    0
# 12    56    1   3       130   256    1        74      1    1
# 13    44    1   2       120   263    0        70      0    0
# ...

# %%
writer = pd.ExcelWriter('binned1.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='numbin1')
writer.save()
