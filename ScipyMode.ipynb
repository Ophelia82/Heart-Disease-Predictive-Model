# %%
import pandas as pd
import numpy as np
from scipy import stats

df= pd.read_excel("rawdata_trimmed.xlsx")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 0     63    1   1       145   233    1        60      0    0
# 1     67    1   4       160   286    0        64      1    2
# 2     67    1   4       120   229    0        78      1    1
# 3     37    1   3       130   250    0        84      0    0
# 4     41    0   2       130   204    0        71      0    0
# 5     56    1   2       120   236    0        73      0    0
# 6     62    0   4       140   268    0        83      0    3
# 7     57    0   4       120   354    0        84      1    0
# 8     63    1   4       130   254    0        75      0    2
# 9     53    1   4       140   203    1        86      1    1
# 10    57    1   4       140   192    0        86      0    0
# 11    56    0   2       140   294    0        85      0    0
# 12    56    1   3       130   256    1        74      1    2
# 13    44    1   2       120   263    0        70      0    0
# ...

# %%
df.groupby(['fbs', 'exang']).apply(pd.DataFrame.mode).reset_index(drop=True)
# Out:
#      age  sex   cp  trestbps  chol  fbs  thalrest  exang  num
# 0   38.0  1.0  4.0     115.0   0.0 -9.0      74.0    0.0  1.0
# 1   51.0  NaN  NaN     130.0   NaN  NaN       NaN    NaN  NaN
# 2   53.0  NaN  NaN       NaN   NaN  NaN       NaN    NaN  NaN
# 3   57.0  1.0  4.0     110.0   0.0 -9.0      70.0    1.0  1.0
# 4    NaN  NaN  NaN     120.0   NaN  NaN       NaN    NaN  NaN
# 5   54.0  1.0  3.0      -9.0   0.0  0.0      -9.0   -9.0  0.0
# 6   61.0  NaN  NaN       NaN   NaN  NaN       NaN    NaN  NaN
# 7   62.0  NaN  NaN       NaN   NaN  NaN       NaN    NaN  NaN
# 8   63.0  NaN  NaN       NaN   NaN  NaN       NaN    NaN  NaN
# 9   65.0  NaN  NaN       NaN   NaN  NaN       NaN    NaN  NaN
# 10  54.0  1.0  4.0     120.0   0.0  0.0      80.0    0.0  0.0
# 11  59.0  1.0  4.0     140.0   0.0  0.0      70.0    1.0  1.0
# 12  51.0  1.0  4.0      -9.0  -9.0  1.0      -9.0   -9.0  1.0
# 13   NaN  NaN  NaN       NaN   0.0  NaN       NaN    NaN  NaN
# ...

# %%
df.groupby(['fbs']).apply(pd.DataFrame.mode).reset_index(drop=True)
# Out:
#    age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 0   53    1   4       110     0   -9        70      0    1
# 1   54    1   4       120     0    0        -9      0    0
# 2   56    1   4        -9     0    1        -9      0    0

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 0   63    1   1       145   233    1        60      0    0
# 1   67    1   4       160   286    0        64      1    2
# 2   67    1   4       120   229    0        78      1    1
# 3   37    1   3       130   250    0        84      0    0
# 4   41    0   2       130   204    0        71      0    0
# 5   56    1   2       120   236    0        73      0    0
# 6   62    0   4       140   268    0        83      0    3
# 7   57    0   4       120   354    0        84      1    0
# 8   63    1   4       130   254    0        75      0    2
# 9   53    1   4       140   203    1        86      1    1

# %%
df.tail(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 888   57    1   4       140     0   -9        78      1    3
# 889   62    1   4       115     0   -9        44      1    1
# 890   59    1   4       110     0   -9        82      0    3
# 891   53    1   3       160     0   -9        91      1    1
# 892   62    1   4       150     0   -9        54      0    3
# 893   54    1   4       180     0   -9        58      0    1
# 894   56    1   4       125     0    1        55      1    3
# 895   56    1   3       125     0   -9        64      0    2
# 896   54    1   4       130     0   -9        58      1    3
# 897   66    0   4       155     0   -9        66      0    1

# %%
df['fbs'].groupby(df['num']).agg([('mode', stats.mode)])
# Out:
#              mode
# num
# 0    ([0], [345])
# 1    ([0], [122])
# 2     ([0], [84])
# 3     ([0], [88])
# 4     ([0], [34])

# %%
df['exang'].groupby(df['num']).agg([('mode', stats.mode)])
# Out:
#              mode
# num
# 0    ([0], [328])
# 1     ([1], [92])
# 2     ([1], [74])
# 3     ([1], [81])
# 4     ([1], [28])

# %%
df.loc[df['fbs'] == -9,'fbs'] = 0

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 0     63    1   1       145   233    1        60      0    0
# 1     67    1   4       160   286    0        64      1    2
# 2     67    1   4       120   229    0        78      1    1
# 3     37    1   3       130   250    0        84      0    0
# 4     41    0   2       130   204    0        71      0    0
# 5     56    1   2       120   236    0        73      0    0
# 6     62    0   4       140   268    0        83      0    3
# 7     57    0   4       120   354    0        84      1    0
# 8     63    1   4       130   254    0        75      0    2
# 9     53    1   4       140   203    1        86      1    1
# 10    57    1   4       140   192    0        86      0    0
# 11    56    0   2       140   294    0        85      0    0
# 12    56    1   3       130   256    1        74      1    2
# 13    44    1   2       120   263    0        70      0    0
# ...

# %%
df.loc[(df['exang'] == -9) & (df['num'] == 0),'exang'] = 0

# %%
df.loc[(df['exang'] == -9) & (df['num'] == 1),'exang'] = 1

# %%
df.loc[(df['exang'] == -9) & (df['num'] == 2),'exang'] = 1

# %%
df.loc[(df['exang'] == -9) & (df['num'] == 3),'exang'] = 1

# %%
df.loc[(df['exang'] == -9) & (df['num'] == 4),'exang'] = 1

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  thalrest  exang  num
# 0     63    1   1       145   233    1        60      0    0
# 1     67    1   4       160   286    0        64      1    2
# 2     67    1   4       120   229    0        78      1    1
# 3     37    1   3       130   250    0        84      0    0
# 4     41    0   2       130   204    0        71      0    0
# 5     56    1   2       120   236    0        73      0    0
# 6     62    0   4       140   268    0        83      0    3
# 7     57    0   4       120   354    0        84      1    0
# 8     63    1   4       130   254    0        75      0    2
# 9     53    1   4       140   203    1        86      1    1
# 10    57    1   4       140   192    0        86      0    0
# 11    56    0   2       140   294    0        85      0    0
# 12    56    1   3       130   256    1        74      1    2
# 13    44    1   2       120   263    0        70      0    0
# ...

# %%
df.iloc[320]
# Out:
# age          58
# sex           1
# cp            4
# trestbps     -9
# chol        203
# fbs           1
# thalrest     -9
# exang         1
# num           1
# Name: 320, dtype: int64

# %%
writer = pd.ExcelWriter('clean1.xlsx', engine = 'xlsxwriter')
df.to_excel(writer, sheet_name='raw')
writer.save()
