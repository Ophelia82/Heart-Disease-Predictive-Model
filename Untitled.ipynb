# %%
pip install xport==2.0.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xport
with open ('GLU_H.xpt', 'rb') as f:
    df = xport.to_dataframe(f)

# %%
df
# Out:
#          SEQN       WTSAF2YR  LBXGLU  LBDGLUSI  PHAFSTHR  PHAFSTMN
# 0     73559.0  142196.890197   193.0    10.713      15.0      51.0
# 1     73561.0  142266.006548   107.0     5.940      14.0      42.0
# 2     73564.0  134054.109760   110.0     6.106      11.0      14.0
# 3     73568.0  216002.505861    89.0     4.940      11.0      51.0
# 4     73574.0       0.000000    84.0     4.663       0.0       9.0
# 5     73576.0   33038.129679    89.0     4.940      12.0      13.0
# 6     73577.0   95784.912822   104.0     5.773      14.0       2.0
# 7     73578.0       0.000000     NaN       NaN      14.0      48.0
# 8     73580.0   76414.039997   103.0     5.718      10.0       7.0
# 9     73581.0   37181.382463   110.0     6.106      12.0      36.0
# 10    73587.0   37066.131850    94.0     5.218      15.0      12.0
# 11    73596.0   36405.455254   107.0     5.940      11.0      11.0
# 12    73597.0       0.000000     NaN       NaN       NaN       NaN
# ...

# %%
writer = pd.ExcelWriter('GLU_H.xlsx', engine = 'xlsxwriter')
df.to_excel(writer, sheet_name='glu')
writer.save()
